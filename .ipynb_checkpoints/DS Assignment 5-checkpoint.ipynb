# %%
import pandas as pd

# %%
import seaborn as sns

# %%
dataset = pd.read_csv('lifeExpectancyAtBirth.csv', sep=',')

# %%
dataset.head()
# Out:
#       Location  Period                         Indicator        Dim1  \
# 0  Afghanistan    2019  Life expectancy at birth (years)  Both sexes
# 1  Afghanistan    2019  Life expectancy at birth (years)        Male
# 2  Afghanistan    2019  Life expectancy at birth (years)      Female
# 3  Afghanistan    2015  Life expectancy at birth (years)  Both sexes
# 4  Afghanistan    2015  Life expectancy at birth (years)        Male
#
#    First Tooltip
# 0          63.21
# 1          63.29
# 2          63.16
# 3          61.65
# 4          61.04

# %%
column=dataset['First Tooltip']

# %%
column.head()
# Out:
# 0    63.21
# 1    63.29
# 2    63.16
# 3    61.65
# 4    61.04
# Name: First Tooltip, dtype: float64

# %%
dataset = dataset.loc[(dataset['Period']==2019) & (dataset['Dim1'].str.match('Both sexes'))]

# %%
dataset.head()
# Out:
#                Location  Period                         Indicator        Dim1  \
# 0           Afghanistan    2019  Life expectancy at birth (years)  Both sexes
# 12              Albania    2019  Life expectancy at birth (years)  Both sexes
# 24              Algeria    2019  Life expectancy at birth (years)  Both sexes
# 36               Angola    2019  Life expectancy at birth (years)  Both sexes
# 48  Antigua and Barbuda    2019  Life expectancy at birth (years)  Both sexes
#
#     First Tooltip
# 0           63.21
# 12          78.00
# 24          77.13
# 36          63.06
# 48          76.45

# %%
dataset
# Out:
#                                 Location  Period  \
# 0                            Afghanistan    2019
# 12                               Albania    2019
# 24                               Algeria    2019
# 36                                Angola    2019
# 48                   Antigua and Barbuda    2019
# ...                                  ...     ...
# 2137  Venezuela (Bolivarian Republic of)    2019
# 2149                            Viet Nam    2019
# 2161                               Yemen    2019
# 2173                              Zambia    2019
# 2185                            Zimbabwe    2019
#
#                              Indicator        Dim1  First Tooltip
# 0     Life expectancy at birth (years)  Both sexes          63.21
# 12    Life expectancy at birth (years)  Both sexes          78.00
# 24    Life expectancy at birth (years)  Both sexes          77.13
# 36    Life expectancy at birth (years)  Both sexes          63.06
# ...

# %%
dataset['First Tooltip'].describe()
# Out:
# count    183.000000
# mean      72.540492
# std        7.129956
# min       50.750000
# 25%       66.550000
# 50%       73.740000
# 75%       77.730000
# max       84.260000
# Name: First Tooltip, dtype: float64

# %%
dataset['First Tooltip'].plot(kind='hist', bins = 10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
dataset['First Tooltip'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
column.head()
# Out:
# 0     63.21
# 12    78.00
# 24    77.13
# 36    63.06
# 48    76.45
# Name: First Tooltip, dtype: float64

# %%
dataset.sort_values(by=['First Tooltip'], ascending=False)
# Out:
#                       Location  Period                         Indicator  \
# 997                      Japan    2019  Life expectancy at birth (years)
# 1897               Switzerland    2019  Life expectancy at birth (years)
# 1573         Republic of Korea    2019  Life expectancy at birth (years)
# 1837                     Spain    2019  Life expectancy at birth (years)
# 1753                 Singapore    2019  Life expectancy at birth (years)
# ...                        ...     ...                               ...
# 1333                Mozambique    2019  Life expectancy at birth (years)
# 661                   Eswatini    2019  Life expectancy at birth (years)
# 1801                   Somalia    2019  Life expectancy at birth (years)
# 373   Central African Republic    2019  Life expectancy at birth (years)
# 1117                   Lesotho    2019  Life expectancy at birth (years)
#
#             Dim1  First Tooltip
# 997   Both sexes          84.26
# ...

# %%
dataset.sort_values(by=['First Tooltip'], ascending = True)
# Out:
#                       Location  Period                         Indicator  \
# 1117                   Lesotho    2019  Life expectancy at birth (years)
# 373   Central African Republic    2019  Life expectancy at birth (years)
# 1801                   Somalia    2019  Life expectancy at birth (years)
# 661                   Eswatini    2019  Life expectancy at birth (years)
# 1333                Mozambique    2019  Life expectancy at birth (years)
# ...                        ...     ...                               ...
# 1837                     Spain    2019  Life expectancy at birth (years)
# 1753                 Singapore    2019  Life expectancy at birth (years)
# 1573         Republic of Korea    2019  Life expectancy at birth (years)
# 1897               Switzerland    2019  Life expectancy at birth (years)
# 997                      Japan    2019  Life expectancy at birth (years)
#
#             Dim1  First Tooltip
# 1117  Both sexes          50.75
# ...
